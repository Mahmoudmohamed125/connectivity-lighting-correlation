# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Loading and Normalizing CSV Data

# %% [markdown]
# ### Relevant Imports

# %%
import geopandas as gpd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### VIIRS Data

# %% [markdown]
# #### Japan

# %% [markdown]
# ##### Light Intensity Normalization

# %%
# Filepath for the outputted CSV file
input_csv = "datasets/inputs/Japan_light_intensity.csv"
output_normalized_csv = "datasets/inputs/Japan_light_intensity_normalized.csv"

# Loading the extracted data
data = pd.read_csv(input_csv)

# Normalizing the light intensity column
data['normalized_light_intensity'] = (data['light_intensity'] - data['light_intensity'].min()) / \
                                     (data['light_intensity'].max() - data['light_intensity'].min())

# Save the normalized data to a new CSV
data.to_csv(output_normalized_csv, index=False)
print(f"Normalized VIIRS data saved to {output_normalized_csv}")
# Out:
# Normalized VIIRS data saved to datasets/inputs/Japan_light_intensity_normalized.csv

# %% [markdown]
# ##### High-Radiance Zones Extraction

# %%
# Filepath for the normalized data
normalized_csv = "datasets/inputs/Japan_light_intensity_normalized.csv"
urban_output_csv = "datasets/processed/Japan_urban_light_intensity.csv"

# Loading the normalized data
normalized_data = pd.read_csv(normalized_csv).drop('light_intensity', axis=1)

# Defining a threshold for high-radiance zones
threshold = 0.3

# Extracting high-radiance zones
urban_data = normalized_data[normalized_data['normalized_light_intensity'] >= threshold]

# Saving the extracted urban areas data
urban_data.to_csv(urban_output_csv, index=False)
print(f"Urban areas data saved to {urban_output_csv}")
# Out:
# Urban areas data saved to datasets/processed/Japan_urban_light_intensity.csv

# %%
urban_data.head()
# Out:
#           longitude   latitude  normalized_light_intensity
# 4484274  141.350003  43.054166                    0.353907
# 4484275  141.354169  43.054166                    0.461180
# 4484276  141.358336  43.054166                    0.354317
# 8986526  141.500003  40.537500                    0.523353
# 8986527  141.504169  40.537500                    0.654899

# %%
urban_data.describe()
# Out:
#         longitude   latitude  normalized_light_intensity
# count   30.000000  30.000000                   30.000000
# mean   138.226253  36.769305                    0.425668
# std      2.961285   3.003967                    0.149639
# min    132.537503  34.220833                    0.300467
# 25%    135.501044  34.670833                    0.338119
# 50%    139.700003  35.677083                    0.375986
# 75%    140.940628  39.333333                    0.450831
# max    141.508336  43.054166                    1.000000

# %% [markdown]
# #### Philippines

# %% [markdown]
# ##### Light Intensity Normalization

# %%
# Filepath for the outputted CSV file
input_csv = "datasets/inputs/Philippines_light_intensity.csv"
output_normalized_csv = "datasets/inputs/Philippines_light_intensity_normalized.csv"

# Loading the extracted data
data = pd.read_csv(input_csv)

# Normalizing the light intensity column
data['normalized_light_intensity'] = (data['light_intensity'] - data['light_intensity'].min()) / \
                                     (data['light_intensity'].max() - data['light_intensity'].min())

# Save the normalized data to a new CSV
data.to_csv(output_normalized_csv, index=False)
print(f"Normalized VIIRS data saved to {output_normalized_csv}")
# Out:
# Normalized VIIRS data saved to datasets/inputs/Philippines_light_intensity_normalized.csv

# %% [markdown]
# ##### High-Radiance Zones Extraction

# %%
# Filepath for the normalized data
normalized_csv = "datasets/inputs/Philippines_light_intensity_normalized.csv"
urban_output_csv = "datasets/processed/Philippines_urban_light_intensity.csv"

# Loading the normalized data
normalized_data = pd.read_csv(normalized_csv).drop('light_intensity', axis=1)

# Defining a threshold for high-radiance zones
threshold = 0.3

# Extracting high-radiance zones
urban_data = normalized_data[normalized_data['normalized_light_intensity'] >= threshold]

# Saving the extracted urban areas data
urban_data.to_csv(urban_output_csv, index=False)
print(f"Urban areas data saved to {urban_output_csv}")
# Out:
# Urban areas data saved to datasets/processed/Philippines_urban_light_intensity.csv

# %%
urban_data.head()
# Out:
#           longitude   latitude  normalized_light_intensity
# 3549238  120.100002  16.125000                    0.361303
# 4522957  120.966669  14.754166                    0.354600
# 4522958  120.970836  14.754166                    0.367698
# 4617666  121.054169  14.620833                    0.307261
# 4620602  120.958336  14.616666                    0.513001

# %%
urban_data.describe()
# Out:
#         longitude    latitude  normalized_light_intensity
# count  152.000000  152.000000                  152.000000
# mean   121.172480   14.234100                    0.411548
# std      0.719162    1.154185                    0.121967
# min    120.100002    6.904166                    0.300249
# 25%    120.983336   14.516666                    0.330265
# 50%    121.004169   14.541666                    0.366314
# 75%    121.050002   14.580208                    0.456612
# max    124.662502   16.125000                    1.000000

# %% [markdown]
# #### Taiwan

# %% [markdown]
# ##### Light Intensity Normalization

# %%
# Filepath for the outputted CSV file
input_csv = "datasets/inputs/Taiwan_light_intensity.csv"
output_normalized_csv = "datasets/inputs/Taiwan_light_intensity_normalized.csv"

# Loading the extracted data
data = pd.read_csv(input_csv)

# Normalizing the light intensity column
data['normalized_light_intensity'] = (data['light_intensity'] - data['light_intensity'].min()) / \
                                     (data['light_intensity'].max() - data['light_intensity'].min())

# Save the normalized data to a new CSV
data.to_csv(output_normalized_csv, index=False)
print(f"Normalized VIIRS data saved to {output_normalized_csv}")
# Out:
# Normalized VIIRS data saved to datasets/inputs/Taiwan_light_intensity_normalized.csv

# %% [markdown]
# ##### High-Radiance Zones Extraction

# %%
# Filepath for the normalized data
normalized_csv = "datasets/inputs/Taiwan_light_intensity_normalized.csv"
urban_output_csv = "datasets/processed/Taiwan_urban_light_intensity.csv"

# Loading the normalized data
normalized_data = pd.read_csv(normalized_csv).drop('light_intensity', axis=1)

# Defining a threshold for high-radiance zones
threshold = 0.3

# Extracting high-radiance zones
urban_data = normalized_data[normalized_data['normalized_light_intensity'] >= threshold]

# Saving the extracted urban areas data
urban_data.to_csv(urban_output_csv, index=False)
print(f"Urban areas data saved to {urban_output_csv}")
# Out:
# Urban areas data saved to datasets/processed/Taiwan_urban_light_intensity.csv

# %%
urban_data.head()
# Out:
#          longitude   latitude  normalized_light_intensity
# 245570  121.750002  25.150000                    0.324514
# 256488  121.241669  25.100000                    0.326211
# 257407  121.237502  25.095833                    0.386666
# 257408  121.241669  25.095833                    0.447414
# 257409  121.245836  25.095833                    0.320626

# %%
urban_data.describe()
# Out:
#         longitude    latitude  normalized_light_intensity
# count  285.000000  285.000000                  285.000000
# mean   120.575105   23.443318                    0.361170
# std      0.483176    0.974436                    0.086443
# min    120.179169   22.491666                    0.300001
# 25%    120.225002   22.637500                    0.315573
# 50%    120.329169   22.995833                    0.335162
# 75%    120.937502   24.145833                    0.370983
# max    121.750002   25.150000                    1.000000

# %% [markdown]
# #### Combining

# %%
# Filepaths for urban light intensity CSVs
urban_csvs = [
    "datasets/processed/Japan_urban_light_intensity.csv",
    "datasets/processed/Philippines_urban_light_intensity.csv",
    "datasets/processed/Taiwan_urban_light_intensity.csv"
]

# Output filepath for the combined CSV
combined_csv = "datasets/processed/combined_urban_light_intensity.csv"

# Initializing an empty list to store DataFrames
urban_dfs = []

# Looping through each file and load data
for csv_path in urban_csvs:
    # Extracting the country name from the file path for tagging
    country_name = csv_path.split("/")[-1].split("_")[0]
    
    # Load the CSV into a DataFrame
    df = pd.read_csv(csv_path)
    
    # Add a column for the country name
    df['country'] = country_name
    
    # Append the DataFrame to the list
    urban_dfs.append(df)

# Concatenate all the DataFrames
combined_df = pd.concat(urban_dfs, ignore_index=True)

# Save the combined DataFrame to a CSV file
combined_df.to_csv(combined_csv, index=False)
print(f"Combined urban light intensity data saved to {combined_csv}")
# Out:
# Combined urban light intensity data saved to datasets/processed/combined_urban_light_intensity.csv

# %% [markdown]
# ### Ookla Data

# %% [markdown]
# #### Aggregate Metrics for Urban Regions

# %%
# File paths
ookla_csv = "datasets/inputs/Global_internet_combined_tiles.csv"
urban_light_csv = "datasets/processed/combined_urban_light_intensity.csv"
output_cleaned_csv = "datasets/processed/cleaned_urban_internet_data.csv"
output_aggregated_csv = "datasets/processed/urban_internet_metrics.csv"

# Load Ookla data as GeoDataFrame
ookla_data = pd.read_csv(ookla_csv)
ookla_gdf = gpd.GeoDataFrame(
    ookla_data,
    geometry=gpd.GeoSeries.from_wkt(ookla_data['geometry']),
    crs="EPSG:4326"
) # type: ignore

# Load and convert urban light intensity data to GeoDataFrame
urban_light_data = pd.read_csv(urban_light_csv)
urban_light_gdf = gpd.GeoDataFrame(
    urban_light_data,
    geometry=gpd.points_from_xy(urban_light_data['longitude'], urban_light_data['latitude']),
    crs="EPSG:4326"
) # type: ignore
ookla_gdf.drop(['index_right'], axis=1, inplace=True)

# Perform spatial join to filter Ookla data for urban regions
urban_internet_data = gpd.sjoin(ookla_gdf, urban_light_gdf, how="inner", predicate="intersects")

# Edit the records with shapeName "Republic Of China" to be "Taiwan"
urban_internet_data.loc[urban_internet_data['shapeName'] == "Republic Of China", 'shapeName'] = "Taiwan"

# Change the name of shapeName column to Country
urban_internet_data.rename(columns={'shapeName': 'country'}, inplace=True)

# Filter only relevant columns for the research scope
urban_internet_data_filtered = urban_internet_data[[
    'country', 'avg_d_kbps', 'avg_u_kbps', 'avg_lat_ms', 'tests', 'geometry', 'normalized_light_intensity'
]]

# Save the cleaned dataset
urban_internet_data_filtered.to_csv(output_cleaned_csv, index=False)
print(f"Cleaned dataset saved to {output_cleaned_csv}")

# Group by urban region or city (use `shapeName` as the grouping column)
grouped = urban_internet_data_filtered.groupby('country')

# Compute average metrics for each region
aggregated_metrics = grouped.agg({
    'avg_d_kbps': 'mean',
    'avg_u_kbps': 'mean',
    'avg_lat_ms': 'mean'
}).reset_index()

# Save the aggregated metrics to CSV
aggregated_metrics.to_csv(output_aggregated_csv, index=False)
print(f"Aggregated internet metrics saved to {output_aggregated_csv}")
# Out:
# C:\Users\bodbo\AppData\Local\Temp\ipykernel_8060\2618180156.py:8: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   ookla_data = pd.read_csv(ookla_csv)
# Cleaned dataset saved to datasets/processed/cleaned_urban_internet_data.csv
# Aggregated internet metrics saved to datasets/processed/urban_internet_metrics.csv

# %% [markdown]
# ## cleaning

# %%
cleaned_data = pd.read_csv("datasets/processed/cleaned_urban_internet_data.csv")

# Step 1: Check for missing values in relevant columns
print(cleaned_data['avg_d_kbps'].isna().sum())
print(cleaned_data['normalized_light_intensity'].isna().sum())

# Step 2: Convert columns to numeric, coercing errors to NaN
cleaned_data['avg_d_kbps'] = pd.to_numeric(cleaned_data['avg_d_kbps'], errors='coerce')
cleaned_data['normalized_light_intensity'] = pd.to_numeric(cleaned_data['normalized_light_intensity'], errors='coerce')

# Step 3: Drop rows with NaN values in critical columns
cleaned_data = cleaned_data.dropna(subset=['avg_d_kbps', 'normalized_light_intensity'])

# Step 4: Verify the data types of the columns
print("\nData types after conversion:")
print(cleaned_data.dtypes)
# Out:
# 0
# 0
#
# Data types after conversion:
# country                        object
# avg_d_kbps                      int64
# avg_u_kbps                      int64
# avg_lat_ms                      int64
# tests                           int64
# geometry                       object
# normalized_light_intensity    float64
# dtype: object

# %% [markdown]
# ## Cleaned data preview

# %%
cleaned_data.columns
# Out:
# Index(['country', 'avg_d_kbps', 'avg_u_kbps', 'avg_lat_ms', 'tests',
#        'geometry', 'normalized_light_intensity', 'country_code'],
#       dtype='object')

# %%
cleaned_data.head()
# Out:
#   country  avg_d_kbps  avg_u_kbps  avg_lat_ms  tests  \
# 0   Japan       90234       97715          83    310
# 1   Japan       79513       79736          72    176
# 2   Japan      101331      103051          72    116
# 3   Japan         672        6698          72      2
# 4   Japan       31011       38553          80      6
#
#                                             geometry  \
# 0  POLYGON ((141.344604492188 43.0568477758455, 1...
# 1  POLYGON ((141.35009765625 43.0568477758455, 14...
# 2  POLYGON ((141.355590820312 43.0568477758455, 1...
# 3  POLYGON ((133.428955078125 34.474863669009, 13...
# 4  POLYGON ((141.498413085938 40.5346767806154, 1...
#
#    normalized_light_intensity
# 0                    0.353907
# 1                    0.461180
# 2                    0.354317
# 3                    0.394868
# 4                    0.706911

# %% [markdown]
# ##  Heatmap: Radiance Intensity vs Internet Speeds

# %%
# Create the pivot table for the heatmap visualization
pivot_data = cleaned_data.pivot_table(
    index='avg_d_kbps', 
    columns='normalized_light_intensity', 
    values='avg_u_kbps',  
    aggfunc='mean'
)

# Visualize the heatmap
plt.figure(figsize=(12, 8))

# Adjust heatmap and font size
heatmap = sns.heatmap(
    pivot_data, 
    cmap="YlGnBu", 
    annot=True, 
    fmt='.2f', 
    linewidths=0.5,
    annot_kws={'size': 8},  # Decrease annotation font size
    cbar_kws={'label': 'Average Upload Speed (avg_u_kbps)'}  # Add color bar label
)

# Rotate the x and y axis labels for better readability
plt.xticks(rotation=45, ha='right', fontsize=10) 
plt.yticks(rotation=0, fontsize=10)  

# Set plot title and labels
heatmap.set_title("Heatmap of Radiance vs Internet Speed", fontsize=14)
plt.xlabel("Normalized Light Intensity", fontsize=12)
plt.ylabel("Average Download Speed (avg_d_kbps)", fontsize=12)

plt.tight_layout()  # Ensure everything fits without overlap
plt.show()

# %% [markdown]
# ## Scatter Plot
# **Objective**: Correlate radiance values with internet performance metrics.

# %%
# Create a scatter plot to visualize the relationship between radiance and download speed

plt.figure(figsize=(10, 6))
sns.regplot(
    data=cleaned_data, 
    x='normalized_light_intensity',  # Radiance values
    y='avg_d_kbps',  # Internet download speed
    scatter_kws={'color': 'blue', 's': 100},  # Customize scatter points
    line_kws={'color': 'red', 'lw': 2},  # Customize regression line
    ci=None  # Disable confidence interval for the regression line
)


plt.title("Scatter Plot with Regression Line: Radiance vs Internet Download Speed", fontsize=16)
plt.xlabel("Normalized Light Intensity", fontsize=12)
plt.ylabel("Average Download Speed (avg_d_kbps)", fontsize=12)


plt.tight_layout()
plt.show()

# %%
# Calculate correlation
correlation = cleaned_data[['normalized_light_intensity', 'avg_d_kbps']].corr()
correlation
# Out:
#                             normalized_light_intensity  avg_d_kbps
# normalized_light_intensity                    1.000000   -0.309611
# avg_d_kbps                                   -0.309611    1.000000

# %% [markdown]
# ## Bar Chart
# **Objective**: Compare internet performance across urban areas with varying light intensity.

# %%
# Group by light intensity and calculate the mean of download speed

grouped_data = cleaned_data.groupby('normalized_light_intensity')['avg_d_kbps'].mean().reset_index()

# Plot the bar chart
plt.figure(figsize=(14, 8))  # Increase figure size for better clarity
sns.barplot(
    data=grouped_data, 
    x='normalized_light_intensity',  # X-axis: Normalized Light Intensity
    y='avg_d_kbps',  # Y-axis: Average Download Speed
    palette="Blues_d"  # Color palette for the bars
)


plt.title("Internet Performance Across Urban Areas with Varying Light Intensity", fontsize=16)
plt.xlabel("Normalized Light Intensity", fontsize=12)
plt.ylabel("Average Download Speed (avg_d_kbps)", fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right', fontsize=10)


plt.tight_layout()  
plt.show()
# Out:
# C:\Users\seigk\AppData\Local\Temp\ipykernel_26740\4262794736.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
print(cleaned_gdf['country'].unique())
# Out:
# ['Japan' 'Taiwan' 'The Philippines']

# %% [markdown]
# ## Geospatial Overlay
# **Objective**: Map urban regions with internet speeds and radiance data layered.

# %%
boundaries_folder = "boundaries"

# Mapping of full country names to abbreviations
country_name_to_code = {
    "Japan": "JPN",
    "Taiwan": "TWN",
    "The Philippines": "PHL"
}

# Map full country names to codes
cleaned_data['country_code'] = cleaned_data['country'].map(country_name_to_code)

# Convert cleaned data to a GeoDataFrame
try:
    cleaned_gdf = gpd.GeoDataFrame(cleaned_data, geometry=gpd.GeoSeries.from_wkt(cleaned_data['geometry']))
except AttributeError:
    raise ValueError("The 'geometry' column must be in WKT format.")

# Initialize plot
fig, ax = plt.subplots(figsize=(12, 10))

for country_name, country_code in country_name_to_code.items():
    # Construct file path dynamically
    boundary_file = os.path.join(boundaries_folder, f"geoBoundaries-{country_code}-ADM0.geojson")
    
    if not os.path.exists(boundary_file):
        print(f"Warning: GeoJSON file for {country_code} not found at {boundary_file}. Skipping.")
        continue
    
    # Load GeoJSON boundary
    boundaries = gpd.read_file(boundary_file)
    
    # Filter data for the country
    country_data = cleaned_gdf[cleaned_gdf['country_code'] == country_code]
    
    if country_data.empty:
        print(f"No data found for {country_name}. Skipping annotation.")
        continue
    
    # Plot country boundaries
    boundaries.plot(ax=ax, color='lightgrey', edgecolor='black', alpha=0.7)
    
    # Plot internet speed data points
    country_data.plot(
        ax=ax, 
        marker='o', 
        color='blue', 
        markersize=10, 
        alpha=0.6, 
        label=f"{country_name} Data"
    )
    
    # Annotate average download speed for each country
    avg_download_speed = country_data['avg_d_kbps'].mean()
    if pd.notna(avg_download_speed):
        boundary_centroid = boundaries.geometry.centroid.unary_union
        if boundary_centroid:
            x, y = boundary_centroid.x, boundary_centroid.y
            ax.text(x, y, f"{country_name}\nAvg Speed: {avg_download_speed:.2f} kbps", 
                    fontsize=10, color='blue', ha='center', bbox=dict(facecolor='white', alpha=0.6))


plt.title("Geospatial Overlay: Internet Speeds and Radiance", fontsize=16)
plt.xlabel("Longitude", fontsize=12)
plt.ylabel("Latitude", fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\seigk\AppData\Local\Temp\ipykernel_26740\1773706205.py:64: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   boundary_centroid = boundaries.geometry.centroid.unary_union
# C:\Users\seigk\AppData\Local\Temp\ipykernel_26740\1773706205.py:64: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   boundary_centroid = boundaries.geometry.centroid.unary_union
# C:\Users\seigk\AppData\Local\Temp\ipykernel_26740\1773706205.py:64: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   boundary_centroid = boundaries.geometry.centroid.unary_union
# ...

# %% [markdown]
# # Line Chart
# # Show trends in radiance and internet speeds over time

# %%
# Ensure a 'time' column exists 
if 'time' not in cleaned_data.columns:
    cleaned_data['time'] = pd.date_range(start='2025-01-01', periods=len(cleaned_data), freq='D')

# Group data by 'time' and 'country_code' for country-specific trends
trend_data = cleaned_data.groupby(['time', 'country_code']).agg({
    'normalized_light_intensity': 'mean',
    'avg_d_kbps': 'mean'
}).reset_index()

# Plot line charts for each country
plt.figure(figsize=(16, 10))

for country_code in trend_data['country_code'].unique():
    country_trend = trend_data[trend_data['country_code'] == country_code]
    
    # Plot normalized light intensity trend
    plt.plot(
        country_trend['time'], 
        country_trend['normalized_light_intensity'], 
        label=f'{country_code} - Radiance', 
        linewidth=2
    )
    
    # Plot internet download speed trend
    plt.plot(
        country_trend['time'], 
        country_trend['avg_d_kbps'], 
        label=f'{country_code} - Download Speed', 
        linewidth=2
    )

# Add labels, legend, and title
plt.title("Trends in Radiance and Internet Speeds Over Time by Country", fontsize=16)
plt.xlabel("Time", fontsize=12)
plt.ylabel("Value", fontsize=12)
plt.legend(fontsize=10, loc='upper right')
plt.grid(alpha=0.3)

# Format x-axis for better readability
plt.xticks(rotation=45, ha='right')

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Hypothesis Testing Code:

# %%
import scipy.stats as stats

# Hypothesis:
# Null Hypothesis (H0): There is no significant correlation between internet performance and nighttime light intensity in urban regions.
# Alternative Hypothesis (H1): Internet performance is significantly correlated with nighttime light intensity in urban regions.

# Perform Pearson correlation test
correlation, p_value = stats.pearsonr(cleaned_data['normalized_light_intensity'], cleaned_data['avg_d_kbps'])

# Print the correlation coefficient and p-value
print(f"Pearson correlation coefficient: {correlation:.4f}")
print(f"P-value: {p_value:.4f}")

# Set significance level (alpha)
alpha = 0.05

# Decision rule based on the p-value
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant correlation between internet performance and nighttime light intensity.")
else:
    print("Fail to reject the null hypothesis: There is no significant correlation between internet performance and nighttime light intensity.")
# Out:
# Pearson correlation coefficient: -0.3096
# P-value: 0.0000
# Reject the null hypothesis: There is a significant correlation between internet performance and nighttime light intensity.

# %%
# Scatter plot with regression line
plt.figure(figsize=(10, 6))

# Create the scatter plot with a regression line
sns.regplot(
    data=cleaned_data, 
    x='normalized_light_intensity',  # Radiance values
    y='avg_d_kbps',  # Internet download speed
    scatter_kws={'color': 'blue', 's': 100},  # Customize scatter points
    line_kws={'color': 'red', 'lw': 2},  # Customize regression line
    ci=None  # Disable confidence interval for the regression line
)

# Title and labels
plt.title("Scatter Plot with Regression Line: Radiance vs Internet Download Speed", fontsize=16)
plt.xlabel("Normalized Light Intensity", fontsize=12)
plt.ylabel("Average Download Speed (avg_d_kbps)", fontsize=12)

# Add Pearson correlation coefficient to the plot
plt.text(
    0.1,  # x position
    1000,  # y position
    f"Pearson Correlation: {correlation:.4f}", 
    fontsize=12, color='black', ha='center', va='center'
)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Predictive Modeling of Internet Speeds Based on Nighttime Light Intensity: Linear and Polynomial Regression Approaches

# %% [markdown]
# # we extract the features (X) and target (Y), and split the data into training and testing sets.

# %%
# Extracting X (Nighttime Light Intensity) and Y (Download Speed)
X = cleaned_data['normalized_light_intensity'].values
Y = cleaned_data['avg_d_kbps'].values

# Splitting the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# # Simple Linear Regression Model

# %%
# Simple Linear Regression Function
def LR(X, Y):
    # Mean X and Y
    mean_X = np.mean(X)
    mean_Y = np.mean(Y)
    # Number of data points
    n = len(X)
    # Using the formula to calculate 'a' and 'b'
    numerator = 0
    denominator = 0
    for i in range(n):
        numerator += (X[i] - mean_X) * (Y[i] - mean_Y)
        denominator += (X[i] - mean_X) ** 2
    a = numerator / denominator
    b = mean_Y - (a * mean_X)
    return a, b

# Train the linear regression model
a, b = LR(X_train, Y_train)

# Predicting values for the training set
Y_pred_train = a * X_train + b

# %% [markdown]
# # Visualization of Simple Linear Regression
# # This section handles the plotting of the data and the regression line for simple linear regression.

# %%
# Plotting Simple Linear Regression
plt.figure(figsize=(10, 6))
plt.title("Simple Linear Regression: Nighttime Light Intensity vs Internet Speed")
plt.scatter(X_train, Y_train, color='blue', label='Actual data')

# Sorting X_train for smooth regression line plotting
sorted_X = np.sort(X_train, axis=0)
Y_pred_sorted = a * sorted_X + b  # Predictions for sorted X values

# Plotting the linear regression line
plt.plot(sorted_X, Y_pred_sorted, color='red', label=f'Linear regression (y = {a:.2f}x + {b:.2f})')
plt.xlabel('Normalized Light Intensity')
plt.ylabel('Download Speed (kbps)')
plt.legend()
plt.show()

# %% [markdown]
# # Polynomial Regression Model
# # This section defines the polynomial regression function, calculates the polynomial features, and computes the weights for the model.

# %%
# Polynomial Regression Function
def polynomial(X, degree):
    X_poly = []
    for n in range(1, degree + 1):
        X_poly.append(X ** n)
    X_poly.append(np.ones(len(X)))  # Adding the bias term (intercept)
    X_poly = np.array(X_poly).T
    return X_poly

# Calculating the weights for Polynomial Regression
def calculate_w(X, Y):
    XT = X.T
    XT_X = XT @ X
    XT_X_inv = np.linalg.pinv(XT_X)
    W = XT_X_inv @ XT @ Y
    return W

# Degree of Polynomial Regression
degree = 3
X_poly_train = polynomial(X_train, degree)
W = calculate_w(X_poly_train, Y_train)

# %% [markdown]
# # Predictions and Visualization for Polynomial Regression
# # This section generates predictions for the test data using the polynomial regression model and visualizes the result.

# %%
# Predicting values for the testing set using Polynomial Regression
X_poly_test = polynomial(X_test, degree)
Y_pred_test = np.matmul(X_poly_test, W)

# Plotting Polynomial Regression
plt.figure(figsize=(10, 6))
plt.title(f"Polynomial Regression with Degree {degree}: Nighttime Light Intensity vs Internet Speed")
plt.scatter(X_train, Y_train, color='blue', label='Actual data')

# Sorting X_test for smooth regression line plotting
sorted_X_test = np.sort(X_test, axis=0)
X_poly_sorted = polynomial(sorted_X_test, degree)
Y_pred_sorted_poly = np.matmul(X_poly_sorted, W)  # Predictions for sorted X values

# Plotting the polynomial regression line
plt.plot(sorted_X_test, Y_pred_sorted_poly, color='green', label=f'Polynomial regression (Degree {degree})')
plt.xlabel('Normalized Light Intensity')
plt.ylabel('Download Speed (kbps)')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# Assuming 'cleaned_data' is your DataFrame and 'normalized_light_intensity' and 'avg_d_kbps' are your features.

# Extracting X (Nighttime Light Intensity) and Y (Download Speed)
X = cleaned_data['normalized_light_intensity'].values
Y = cleaned_data['avg_d_kbps'].values

# Splitting the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Simple Linear Regression Function
def LR(X, Y):
    # Mean X and Y
    mean_X = np.mean(X)
    mean_Y = np.mean(Y)
    # Number of data points
    n = len(X)
    # Using the formula to calculate 'a' and 'b'
    numerator = 0
    denominator = 0
    for i in range(n):
        numerator += (X[i] - mean_X) * (Y[i] - mean_Y)
        denominator += (X[i] - mean_X) ** 2
    a = numerator / denominator
    b = mean_Y - (a * mean_X)
    return a, b

# Train the linear regression model
a, b = LR(X_train, Y_train)

# Predicting values for the training set
Y_pred_train = a * X_train + b

# Plotting Simple Linear Regression
plt.figure(figsize=(10, 6))
plt.title("Simple Linear Regression: Nighttime Light Intensity vs Internet Speed")
plt.scatter(X_train, Y_train, color='blue', label='Actual data')

# Sorting X_train for smooth regression line plotting
sorted_X = np.sort(X_train, axis=0)
Y_pred_sorted = a * sorted_X + b  # Predictions for sorted X values

# Plotting the linear regression line
plt.plot(sorted_X, Y_pred_sorted, color='red', label=f'Linear regression (y = {a:.2f}x + {b:.2f})')
plt.xlabel('Normalized Light Intensity')
plt.ylabel('Download Speed (kbps)')
plt.legend()
plt.show()

# Polynomial Regression Function
def polynomial(X, degree):
    X_poly = []
    for n in range(1, degree + 1):
        X_poly.append(X ** n)
    X_poly.append(np.ones(len(X)))  # Adding the bias term (intercept)
    X_poly = np.array(X_poly).T
    return X_poly

# Calculating the weights for Polynomial Regression
def calculate_w(X, Y):
    XT = X.T
    XT_X = XT @ X
    XT_X_inv = np.linalg.pinv(XT_X)
    W = XT_X_inv @ XT @ Y
    return W

# Degree of Polynomial Regression
degree = 3
X_poly_train = polynomial(X_train, degree)
W = calculate_w(X_poly_train, Y_train)

# Predicting values for the testing set using Polynomial Regression
X_poly_test = polynomial(X_test, degree)
Y_pred_test = np.matmul(X_poly_test, W)

# Plotting Polynomial Regression
plt.figure(figsize=(10, 6))
plt.title(f"Polynomial Regression with Degree {degree}: Nighttime Light Intensity vs Internet Speed")
plt.scatter(X_train, Y_train, color='blue', label='Actual data')

# Sorting X_test for smooth regression line plotting
sorted_X_test = np.sort(X_test, axis=0)
X_poly_sorted = polynomial(sorted_X_test, degree)
Y_pred_sorted_poly = np.matmul(X_poly_sorted, W)  # Predictions for sorted X values

# Plotting the polynomial regression line
plt.plot(sorted_X_test, Y_pred_sorted_poly, color='green', label=f'Polynomial regression (Degree {degree})')
plt.xlabel('Normalized Light Intensity')
plt.ylabel('Download Speed (kbps)')
plt.legend()
plt.show()

# Performance Evaluation
TSS = sum([(y - np.mean(Y_train)) ** 2 for y in Y_train])
RSS_linear = sum([(y - y_pred) ** 2 for y, y_pred in zip(Y_train, Y_pred_train)])
RSS_poly = sum([(y - y_pred) ** 2 for y, y_pred in zip(Y_test, Y_pred_test)])

R2_linear = 1 - RSS_linear / TSS
R2_poly = 1 - RSS_poly / TSS

print(f"Linear Regression R²: {R2_linear:.4f}")
print(f"Polynomial Regression R²: {R2_poly:.4f}")
# Out:
# Linear Regression R²: 0.1100
# Polynomial Regression R²: 0.7952

# %% [markdown]
# #  Model Evaluation
# # In this section, we calculate and compare the R² values for both the simple linear regression model and the polynomial regression model.

# %%
# Performance Evaluation
TSS = sum([(y - np.mean(Y_train)) ** 2 for y in Y_train])
RSS_linear = sum([(y - y_pred) ** 2 for y, y_pred in zip(Y_train, Y_pred_train)])
RSS_poly = sum([(y - y_pred) ** 2 for y, y_pred in zip(Y_test, Y_pred_test)])

R2_linear = 1 - RSS_linear / TSS
R2_poly = 1 - RSS_poly / TSS

print(f"Linear Regression R²: {R2_linear:.4f}")
print(f"Polynomial Regression R²: {R2_poly:.4f}")
# Out:
# Linear Regression R²: 0.1100
# Polynomial Regression R²: 0.7952

# %%
# Plotting both Simple Linear and Polynomial Regression on the same graph
plt.figure(figsize=(10, 6))
plt.title("Regression Comparison: Nighttime Light Intensity vs Internet Speed")

# Scatter plot for the actual data
plt.scatter(X_train, Y_train, color='blue', label='Actual data')

# Simple Linear Regression line (red)
sorted_X = np.sort(X_train, axis=0)
Y_pred_sorted = a * sorted_X + b  # Predictions for sorted X values
plt.plot(sorted_X, Y_pred_sorted, color='red', label=f'Linear regression (y = {a:.2f}x + {b:.2f})')

# Polynomial Regression line (green)
X_poly_train = polynomial(X_train, degree)
W = calculate_w(X_poly_train, Y_train)
sorted_X_test = np.sort(X_test, axis=0)
X_poly_sorted = polynomial(sorted_X_test, degree)
Y_pred_sorted_poly = np.matmul(X_poly_sorted, W)  # Predictions for sorted X values
plt.plot(sorted_X_test, Y_pred_sorted_poly, color='green', label=f'Polynomial regression (Degree {degree})')

# Labels and legend
plt.xlabel('Normalized Light Intensity')
plt.ylabel('Download Speed (kbps)')
plt.legend()
plt.show()
